# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importing Data File

# %%
food_data = pd.read_csv('foodstruct_nutritional_facts.csv') 
food_data.head()
# Out:
#      Food Name Category Name  Calcium  Calories  Carbs  Cholesterol  Copper
# 0      Acerola        Fruits     12.0      32.0   77.0          0.0     9.0  \
# 1        Apple        Fruits      6.0      52.0   14.0          0.0     3.0
# 2      Apricot        Fruits     13.0      48.0   11.0          0.0     8.0
# 3  Dried fruit        Fruits     55.0     241.0   63.0          0.0    34.0
# 4      Avocado        Fruits     12.0     160.0   85.0          0.0    19.0
#
#    Fats  Fiber  Folate  ...  Vitamin D  Vitamin E  Vitamin K  Omega-3 - ALA
# 0   3.0   11.0    14.0  ...        NaN        NaN        NaN            NaN  \
# 1  17.0   24.0     3.0  ...        0.0       18.0       22.0            NaN
# 2  39.0    2.0     9.0  ...        0.0       89.0       33.0            NaN
# 3  51.0   73.0    10.0  ...        0.0       43.0       31.0            NaN
# 4  15.0   67.0    81.0  ...        0.0       21.0       21.0           11.0
#
#    Omega-6 - Eicosadienoic acid  Omega-6 - Gamma-linoleic acid
# 0                           NaN                            NaN  \
# 1                           NaN                            NaN
# 2                           NaN                            NaN
# 3                           NaN                            NaN
# 4                           0.0                            2.0
#
#    Omega-3 - Eicosatrienoic acid  Omega-6 - Dihomo-gamma-linoleic acid
# 0                            NaN                                   NaN  \
# 1                            NaN                                   NaN
# 2                            NaN                                   NaN
# 3                            NaN                                   NaN
# 4                            NaN                                   NaN
#
#    Omega-6 - Linoleic acid  Omega-6 - Arachidonic acid
# 0                      NaN                         NaN
# 1                      NaN                         NaN
# 2                      NaN                         NaN
# 3                      NaN                         NaN
# 4                      NaN                         NaN
#
# [5 rows x 59 columns]

# %% [markdown]
# ## EDA Part I: Cleaning Data

# %%
# Checking all column names 
food_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1171 entries, 0 to 1170
# Data columns (total 59 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Food Name                             1171 non-null   object
#  1   Category Name                         1171 non-null   object
#  2   Calcium                               1146 non-null   float64
#  3   Calories                              1171 non-null   float64
#  4   Carbs                                 1171 non-null   float64
#  5   Cholesterol                           1116 non-null   float64
#  6   Copper                                1092 non-null   float64
#  7   Fats                                  1171 non-null   float64
#  8   Fiber                                 1073 non-null   float64
#  9   Folate                                1069 non-null   float64
#  10  Iron                                  1151 non-null   float64
#  11  Magnesium                             1111 non-null   float64
#  12  Monounsaturated Fat                   1063 non-null   float64
#  13  Net carbs                             1170 non-null   float64
#  14  Omega-3 - DHA                         900 non-null    float64
#  15  Omega-3 - DPA                         893 non-null    float64
#  16  Omega-3 - EPA                         901 non-null    float64
#  17  Phosphorus                            1124 non-null   float64
#  18  Polyunsaturated fat                   1063 non-null   float64
#  19  Potassium                             1127 non-null   float64
#  20  Protein                               1171 non-null   float64
#  21  Saturated Fat                         1091 non-null   float64
#  22  Selenium                              1018 non-null   float64
#  23  Sodium                                1150 non-null   float64
#  24  Trans Fat                             630 non-null    float64
#  25  Vitamin A                             1115 non-null   float64
#  26  Vitamin A RAE                         1054 non-null   float64
#  27  Vitamin B1                            1113 non-null   float64
#  28  Vitamin B12                           1081 non-null   float64
#  29  Vitamin B2                            1114 non-null   float64
#  30  Vitamin B3                            1113 non-null   float64
#  31  Vitamin B5                            975 non-null    float64
#  32  Vitamin B6                            1089 non-null   float64
#  33  Vitamin C                             1121 non-null   float64
#  34  Zinc                                  1106 non-null   float64
#  35  Choline                               730 non-null    float64
#  36  Fructose                              301 non-null    float64
#  37  Histidine                             709 non-null    float64
#  38  Isoleucine                            713 non-null    float64
#  39  Leucine                               713 non-null    float64
#  40  Lysine                                721 non-null    float64
#  41  Manganese                             1012 non-null   float64
#  42  Methionine                            718 non-null    float64
#  43  Phenylalanine                         710 non-null    float64
#  44  Starch                                198 non-null    float64
#  45  Sugar                                 871 non-null    float64
#  46  Threonine                             712 non-null    float64
#  47  Tryptophan                            710 non-null    float64
#  48  Valine                                713 non-null    float64
#  49  Vitamin D                             826 non-null    float64
#  50  Vitamin E                             814 non-null    float64
#  51  Vitamin K                             789 non-null    float64
#  52  Omega-3 - ALA                         176 non-null    float64
#  53  Omega-6 - Eicosadienoic acid          264 non-null    float64
#  54  Omega-6 - Gamma-linoleic acid         170 non-null    float64
#  55  Omega-3 - Eicosatrienoic acid         113 non-null    float64
#  56  Omega-6 - Dihomo-gamma-linoleic acid  118 non-null    float64
#  57  Omega-6 - Linoleic acid               140 non-null    float64
#  58  Omega-6 - Arachidonic acid            1 non-null      float64
# dtypes: float64(57), object(2)
# memory usage: 539.9+ KB

# %%
# Checking how many unique food groups fall under the categories column 
food_groups_counts = food_data['Category Name'].value_counts()
food_groups_counts
# Out:
# Category Name
# Baked Products                     106
# Meat                               100
# Sweets                              96
# Meals, Entrees, and Side Dishes     90
# Vegetables                          90
# Fruits                              88
# Beverages                           84
# Seafood                             83
# Soups                               67
# Grains                              66
# Greens                              60
# Dairy                               58
# Oils and Sauces                     54
# Spices                              46
# Fast Foods                          45
# Nuts                                27
# Mushrooms                            8
# Baby Foods                           3
# Name: count, dtype: int64

# %% [markdown]
# According to the National Institute of Health (NIH) there are 8 major food groups...
#  - Vegetables
#  - Fruits
#  - Grains
#  - Protein Foods
#  - Dairy
#  - Oils and Solid Fats
#  - Added Sugars
#  - Beverages
#
# The food_data Categories are not sorted this way so we need to reorganize how things are classified to align them with the NIH food groups. Below is an outline of how the Categories above will be adjusted to suit the NIH classifications.
#
# | NIH Food Group       | Data Categories                |
# |----------------------|---------------------------------|
# | Vegetables           | Vegetables, Greens, Mushrooms   |
# | Fruits               | Fruits                          |
# | Grains               | Grains                          |
# | Protein Foods        | Meat, Seafood, Nuts             |
# | Dairy                | Dairy                           |
# | Oils and Solid Fats  | Oils and Sauces                 |
# | Added Sugars         | Baked Products, Sweets          |
# | Beverages            | Beverages                       |
#
#
# Categories that are being filtered out: Baby Foods, Fast Foods, Spices, Soups, Meals, Entrees, and Side Dishes
#
# [Source](https://www.nia.nih.gov/health/healthy-eating-nutrition-and-diet/healthy-eating-you-age-know-your-food-groups#grains)

# %%
# Clean and standardize the 'Category Name' column
food_data['Category Name'] = food_data['Category Name'].str.strip().str.title()

# Define the mapping from old categories to NIH Food Groups
category_mapping = {
    'Vegetables': 'Vegetables',
    'Greens': 'Vegetables',
    'Mushrooms': 'Vegetables',
    'Fruits': 'Fruits',
    'Grains': 'Grains',
    'Meat': 'Protein Foods',
    'Seafood': 'Protein Foods',
    'Nuts': 'Protein Foods',
    'Dairy': 'Dairy',
    'Oils': 'Oils and Solid Fats',
    'Sauces': 'Oils and Solid Fats',
    'Baked Products': 'Added Sugars',
    'Sweets': 'Added Sugars',
    'Beverages': 'Beverages'}


# Map the old categories to the new NIH Food Groups
food_data['NIH_Food_Group'] = food_data['Category Name'].map(category_mapping)

# Identify and handle unmapped categories
unmapped = food_data[food_data['NIH_Food_Group'].isnull()]['Category Name'].unique()
if len(unmapped) > 0:
    print('Categories not mapped:')
    print(unmapped)
    # Decide how to handle these categories
    # For example, assign to 'Other'
    food_data['NIH_Food_Group'] = food_data['NIH_Food_Group'].fillna('Other')

# Verify the mapping
print('Mapped NIH Food Groups:')
print(food_data['NIH_Food_Group'].value_counts())

# Save the updated dataset
food_data.to_csv('food_data_nih.csv', index=False)
# Out:
# Categories not mapped:
# ['Spices' 'Oils And Sauces' 'Soups' 'Fast Foods'
#  'Meals, Entrees, And Side Dishes' 'Baby Foods']
# Mapped NIH Food Groups:
# NIH_Food_Group
# Other            305
# Protein Foods    210
# Added Sugars     202
# Vegetables       158
# Fruits            88
# Beverages         84
# Grains            66
# Dairy             58
# Name: count, dtype: int64

# %%
nih_food_data = pd.read_csv('food_data_nih.csv')
nih_food_data.head()
# Out:
#      Food Name Category Name  Calcium  Calories  Carbs  Cholesterol  Copper
# 0      Acerola        Fruits     12.0      32.0   77.0          0.0     9.0  \
# 1        Apple        Fruits      6.0      52.0   14.0          0.0     3.0
# 2      Apricot        Fruits     13.0      48.0   11.0          0.0     8.0
# 3  Dried fruit        Fruits     55.0     241.0   63.0          0.0    34.0
# 4      Avocado        Fruits     12.0     160.0   85.0          0.0    19.0
#
#    Fats  Fiber  Folate  ...  Vitamin E  Vitamin K  Omega-3 - ALA
# 0   3.0   11.0    14.0  ...        NaN        NaN            NaN  \
# 1  17.0   24.0     3.0  ...       18.0       22.0            NaN
# 2  39.0    2.0     9.0  ...       89.0       33.0            NaN
# 3  51.0   73.0    10.0  ...       43.0       31.0            NaN
# 4  15.0   67.0    81.0  ...       21.0       21.0           11.0
#
#    Omega-6 - Eicosadienoic acid  Omega-6 - Gamma-linoleic acid
# 0                           NaN                            NaN  \
# 1                           NaN                            NaN
# 2                           NaN                            NaN
# 3                           NaN                            NaN
# 4                           0.0                            2.0
#
#    Omega-3 - Eicosatrienoic acid  Omega-6 - Dihomo-gamma-linoleic acid
# 0                            NaN                                   NaN  \
# 1                            NaN                                   NaN
# 2                            NaN                                   NaN
# 3                            NaN                                   NaN
# 4                            NaN                                   NaN
#
#    Omega-6 - Linoleic acid  Omega-6 - Arachidonic acid  NIH_Food_Group
# 0                      NaN                         NaN          Fruits
# 1                      NaN                         NaN          Fruits
# 2                      NaN                         NaN          Fruits
# 3                      NaN                         NaN          Fruits
# 4                      NaN                         NaN          Fruits
#
# [5 rows x 60 columns]

# %%
# We are going to move the NIH Food Groups column to the 2nd position to the left
# Get the list of columns
columns = nih_food_data.columns.tolist()

# Remove 'NIH_Food_Group' from its current position
columns.remove('NIH_Food_Group')

# Insert 'NIH_Food_Group' at position 1 (after the first column)
columns.insert(1, 'NIH_Food_Group')

# Reorder the DataFrame
nih_food_data = nih_food_data[columns]
nih_food_data.head()
# Out:
#      Food Name NIH_Food_Group Category Name  Calcium  Calories  Carbs
# 0      Acerola         Fruits        Fruits     12.0      32.0   77.0  \
# 1        Apple         Fruits        Fruits      6.0      52.0   14.0
# 2      Apricot         Fruits        Fruits     13.0      48.0   11.0
# 3  Dried fruit         Fruits        Fruits     55.0     241.0   63.0
# 4      Avocado         Fruits        Fruits     12.0     160.0   85.0
#
#    Cholesterol  Copper  Fats  Fiber  ...  Vitamin D  Vitamin E  Vitamin K
# 0          0.0     9.0   3.0   11.0  ...        NaN        NaN        NaN  \
# 1          0.0     3.0  17.0   24.0  ...        0.0       18.0       22.0
# 2          0.0     8.0  39.0    2.0  ...        0.0       89.0       33.0
# 3          0.0    34.0  51.0   73.0  ...        0.0       43.0       31.0
# 4          0.0    19.0  15.0   67.0  ...        0.0       21.0       21.0
#
#    Omega-3 - ALA  Omega-6 - Eicosadienoic acid  Omega-6 - Gamma-linoleic acid
# 0            NaN                           NaN                            NaN  \
# 1            NaN                           NaN                            NaN
# 2            NaN                           NaN                            NaN
# 3            NaN                           NaN                            NaN
# 4           11.0                           0.0                            2.0
#
#    Omega-3 - Eicosatrienoic acid  Omega-6 - Dihomo-gamma-linoleic acid
# 0                            NaN                                   NaN  \
# 1                            NaN                                   NaN
# 2                            NaN                                   NaN
# 3                            NaN                                   NaN
# 4                            NaN                                   NaN
#
#    Omega-6 - Linoleic acid  Omega-6 - Arachidonic acid
# 0                      NaN                         NaN
# 1                      NaN                         NaN
# 2                      NaN                         NaN
# 3                      NaN                         NaN
# 4                      NaN                         NaN
#
# [5 rows x 60 columns]

# %% [markdown]
# ## EDA Part II: Selecting & Visualizing Nutrients

# %% [markdown]
# Each food group has some predominant nutrient characteristics. Although these may not be unique, we want to select nutrients that are characteristic of some food groups and are not of others. Below are each of the food groups and some of their defining nutrients.
#
# | NIH Food Group       | Defining Nutrients               |
# |----------------------|---------------------------------|
# | Vegetables           | Vitamins, Minerals, Carbohydrates, Fibre |
# | Fruits               | Vitamins, Minerals, Carbohydrates, Fibre |
# | Grains               | Carbohydrates, Fibre, B Vitamins         |
# | Protein Foods        | Proteins             |
# | Dairy                | Calcium, Potassium, Vitamin D,           |
# | Oils and Solid Fats  | High Calories, Vitamin E, Fats                 |
# | Added Sugars         | Sugar         |
# | Beverages            | Low Fat                       |
#
# Given each food group has several different characteristics we will go with the nutrients that must be legally put on nutrition labels in Canada. Hence the following...
# - Calories
# - Total Fat
# - Saturated Fat
# - Trans Fat
# - Cholesterol
# - Sodium
# - Total Carbohydrates
# - Dietary Fibre
# - Sugar
# - Protein
# - Calcium
# - Potassium
# - Iron

# %%
nutrients = ['Calories', 'Fats', 'Saturated Fat', 'Trans Fat', 'Cholesterol',  
                        'Sodium', 'Carbs', 'Fiber', 'Sugar', 'Protein', 
                        'Calcium', 'Potassium', 'Iron'
                        ]

nih_food_data[nutrients].head()
# Out:
#    Calories  Fats  Saturated Fat  Trans Fat  Cholesterol  Sodium  Carbs
# 0      32.0   3.0            7.0        0.0          0.0     7.0   77.0  \
# 1      52.0  17.0            3.0        0.0          0.0     1.0   14.0
# 2      48.0  39.0            3.0        0.0          0.0     1.0   11.0
# 3     241.0  51.0            2.0        NaN          0.0    10.0   63.0
# 4     160.0  15.0           21.0        0.0          0.0     7.0   85.0
#
#    Fiber  Sugar  Protein  Calcium  Potassium  Iron
# 0   11.0    NaN      4.0     12.0      146.0   2.0
# 1   24.0   10.0     26.0      6.0      107.0  12.0
# 2    2.0   92.0     14.0     13.0      259.0  39.0
# 3   73.0   53.0     34.0     55.0     1162.0  27.0
# 4   67.0   66.0      2.0     12.0      485.0  55.0

# %%
# The nutrients are supposed to be our Explanatory Variable which we will define as X
X = nih_food_data[nutrients]

# The food groups are supposed to be our Response Variable which we will define as Y
y = nih_food_data['NIH_Food_Group']

# %%
print(X.describe())
# Out:
#           Calories         Fats  Saturated Fat   Trans Fat  Cholesterol
# count  1171.000000  1171.000000    1091.000000  630.000000  1116.000000  \
# mean    224.772844    28.842015      25.215399    4.728571    30.883513
# std     185.963326    26.333005      26.166587   13.205637    85.313975
# min       0.000000     0.000000       0.000000    0.000000     0.000000
# 25%      72.000000    11.000000       4.000000    0.000000     0.000000
# 50%     182.000000    21.000000      17.000000    0.000000     0.000000
# 75%     342.500000    42.000000      36.000000    2.000000    33.250000
# max     902.000000   100.000000     153.000000   99.000000  1085.000000
#
#              Sodium        Carbs        Fiber       Sugar      Protein
# count   1150.000000  1171.000000  1073.000000  871.000000  1171.000000  \
# mean     352.151304    38.228864    16.265610   31.506315    30.093083
# std     1474.430022    28.801244    21.069034   27.877064    25.919119
# min        0.000000     0.000000     0.000000    0.000000     0.000000
# 25%        9.000000    14.000000     0.000000    7.500000    12.000000
# 50%       73.000000    33.000000     8.000000   25.000000    22.000000
# 75%      414.000000    63.000000    25.000000   49.000000    43.000000
# max    38758.000000   100.000000    99.000000  100.000000    98.000000
#
#            Calcium     Potassium         Iron
# count  1146.000000   1127.000000  1151.000000
# mean     99.467714    305.349601    28.731538
# std     264.600289    590.352550    25.063295
# min       0.000000      0.000000     0.000000
# 25%      12.000000    114.500000    11.000000
# 50%      31.000000    204.000000    21.000000
# 75%      88.000000    352.500000    39.000000
# max    5876.000000  16500.000000   124.000000

# %%
# Removing other group from our analysis since it technically isnt a food group
nih_food_data = nih_food_data[nih_food_data['NIH_Food_Group'] != 'Other']
nih_food_data.head()
# Out:
#      Food Name NIH_Food_Group Category Name  Calcium  Calories  Carbs
# 0      Acerola         Fruits        Fruits     12.0      32.0   77.0  \
# 1        Apple         Fruits        Fruits      6.0      52.0   14.0
# 2      Apricot         Fruits        Fruits     13.0      48.0   11.0
# 3  Dried fruit         Fruits        Fruits     55.0     241.0   63.0
# 4      Avocado         Fruits        Fruits     12.0     160.0   85.0
#
#    Cholesterol  Copper  Fats  Fiber  ...  Vitamin D  Vitamin E  Vitamin K
# 0          0.0     9.0   3.0   11.0  ...        NaN        NaN        NaN  \
# 1          0.0     3.0  17.0   24.0  ...        0.0       18.0       22.0
# 2          0.0     8.0  39.0    2.0  ...        0.0       89.0       33.0
# 3          0.0    34.0  51.0   73.0  ...        0.0       43.0       31.0
# 4          0.0    19.0  15.0   67.0  ...        0.0       21.0       21.0
#
#    Omega-3 - ALA  Omega-6 - Eicosadienoic acid  Omega-6 - Gamma-linoleic acid
# 0            NaN                           NaN                            NaN  \
# 1            NaN                           NaN                            NaN
# 2            NaN                           NaN                            NaN
# 3            NaN                           NaN                            NaN
# 4           11.0                           0.0                            2.0
#
#    Omega-3 - Eicosatrienoic acid  Omega-6 - Dihomo-gamma-linoleic acid
# 0                            NaN                                   NaN  \
# 1                            NaN                                   NaN
# 2                            NaN                                   NaN
# 3                            NaN                                   NaN
# 4                            NaN                                   NaN
#
#    Omega-6 - Linoleic acid  Omega-6 - Arachidonic acid
# 0                      NaN                         NaN
# 1                      NaN                         NaN
# 2                      NaN                         NaN
# 3                      NaN                         NaN
# 4                      NaN                         NaN
#
# [5 rows x 60 columns]

# %%
# Box plots demonstrating distributions for each nutrient 

# Create subplots with 4 rows and 4 columns 
fig, axes = plt.subplots(4, 4, figsize = (20, 16))  # Adjust the figsize as needed

# Flatten the axes array to easily iterate over it
axes = axes.flatten()

# Different colours for each boxplot
palette = sns.color_palette('colorblind', len(nutrients)) 

# y-axis limits for certain nutrients
y_axis_limits = {
    'Cholesterol': (0, 250),
    'Sodium': (0, 2000),
    'Potassium': (0, 1000),
    'Calcium': (0, 1250)
}

# y-axis limits for certain nutrients
x_axis_limits = {
    'Cholesterol': (0, 150),
    'Sodium': (0, 2000),
    'Potassium': (0, 1250),
    'Calcium': (0, 1000), 
    'Trans Fat': (0, 40)
}

# Loop through each feature and create a boxplot in the corresponding subplot
for i, nutrient in enumerate(nutrients):
    sns.boxplot(x = X[nutrient], ax = axes[i], color = palette[i])
    axes[i].set_title(f'Box Plot of {nutrient}')
    axes[i].set_xlabel(nutrient)

    if nutrient in x_axis_limits:
        axes[i].set_xlim(x_axis_limits[nutrient]) 
        
# Remove any unused subplots if there are fewer than 12 features
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])
    
plt.tight_layout()
plt.show()

# %%
# Box plots demonstrating distributions for each nutrient for every food group 

# Create subplots with 2 rows and 7 columns
fig, axes = plt.subplots(7, 2, figsize = (12, 28))  # Adjust figsize as necessary

# Flatten the axes array to easily iterate over it
axes = axes.flatten()

# Different colours for each boxplot
palette = sns.color_palette('colorblind', len(nutrients))

# y-axis limits for certain nutrients
y_axis_limits = {
    'Cholesterol': (0, 250),
    'Sodium': (0, 2000),
    'Potassium': (0, 1000),
    'Calcium': (0, 1250)
}

# Loop through each nutrient and create a boxplot in the corresponding subplot
for i, nutrient in enumerate(nutrients):
    sns.boxplot(x = 'NIH_Food_Group', y = nutrient, data = nih_food_data, color = palette[i], ax = axes[i])
    axes[i].set_title(f'{nutrient} by NIH Food Group')
    axes[i].set_ylabel(nutrient)
    axes[i].tick_params(axis='x', rotation=45)
    
    if nutrient in y_axis_limits:
        axes[i].set_ylim(y_axis_limits[nutrient])

# Remove any extra subplots if there are fewer than 14 nutrients
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %%
# Replace NaN values with the column mean for each nutrient
for nutrient in nutrients:
    nih_food_data[nutrient].fillna(nih_food_data[nutrient].mean(), inplace=True)

# %% [markdown]
# ## Statistical Testing
#
# First we are trying to see if there are significant differences between the nutrient distributions for each nutrient when compared to the food groups. We need to try and pick the correct statistical test. We will start by running a Shapiro-Wilk Test to see if the residuals of our nutrients are normall distributed or not. If they are Normally Distributed we can proceed with ANOVA for testing statistical significance. If they are not Normally Distributed we will proceed with the Kruskall-Wallis test.

# %%
from scipy.stats import shapiro

for nutrient in nutrients: 
    # Fit the ANOVA model
    model = ols(f'Q("{nutrient}") ~ C(NIH_Food_Group)', data=nih_food_data).fit()
    
    # Extract residuals from the ANOVA model
    residuals = model.resid
    
    # Perform Shapiro-Wilk test for normality on the residuals
    stat, p_value = shapiro(residuals)
    
    print(f"\nShapiro-Wilk Test for Residuals of {nutrient}:")
    print(f"Statistic: {stat}, p-value: {p_value}")
    
    # Check if residuals are normally distributed
    if p_value > 0.05:
        print(f"Residuals for {nutrient} are normally distributed (fail to reject the null hypothesis).")
    else:
        print(f"Residuals for {nutrient} are not normally distributed (reject the null hypothesis).")
# Out:
# Shapiro-Wilk Test for Residuals of Calories:
# Statistic: 0.8965773582458496, p-value: 2.3655567727816603e-27
# Residuals for Calories are not normally distributed (reject the null hypothesis).
#
# Shapiro-Wilk Test for Residuals of Fats:
# Statistic: 0.8978256583213806, p-value: 3.2847405425144954e-27
# Residuals for Fats are not normally distributed (reject the null hypothesis).
#
# Shapiro-Wilk Test for Residuals of Saturated Fat:
# Statistic: 0.8931936025619507, p-value: 9.863915025546582e-28
# Residuals for Saturated Fat are not normally distributed (reject the null hypothesis).
#
# Shapiro-Wilk Test for Residuals of Trans Fat:
# Statistic: 0.4205676317214966, p-value: 0.0
# Residuals for Trans Fat are not normally distributed (reject the null hypothesis).
#
# Shapiro-Wilk Test for Residuals of Cholesterol:
# Statistic: 0.39676952362060547, p-value: 0.0
# Residuals for Cholesterol are not normally distributed (reject the null hypothesis).
#
# Shapiro-Wilk Test for Residuals of Sodium:
# Statistic: 0.17079883813858032, p-value: 0.0
# Residuals for Sodium are not normally distributed (reject the null hypothesis).
#
# Shapiro-Wilk Test for Residuals of Carbs:
# Statistic: 0.9576316475868225, p-value: 6.3368429027696955e-18
# Residuals for Carbs are not normally distributed (reject the null hypothesis).
#
# Shapiro-Wilk Test for Residuals of Fiber:
# Statistic: 0.8207647800445557, p-value: 3.1951883367868324e-34
# Residuals for Fiber are not normally distributed (reject the null hypothesis).
#
# Shapiro-Wilk Test for Residuals of Sugar:
# Statistic: 0.9502418637275696, p-value: 1.8212751574797752e-19
# Residuals for Sugar are not normally distributed (reject the null hypothesis).
#
# Shapiro-Wilk Test for Residuals of Protein:
# Statistic: 0.9188624024391174, p-value: 1.4068994048351369e-24
# Residuals for Protein are not normally distributed (reject the null hypothesis).
#
# Shapiro-Wilk Test for Residuals of Calcium:
# Statistic: 0.38641393184661865, p-value: 0.0
# Residuals for Calcium are not normally distributed (reject the null hypothesis).
#
# Shapiro-Wilk Test for Residuals of Potassium:
# Statistic: 0.2826625108718872, p-value: 0.0
# Residuals for Potassium are not normally distributed (reject the null hypothesis).
#
# Shapiro-Wilk Test for Residuals of Iron:
# Statistic: 0.8960386514663696, p-value: 2.055003458144135e-27
# Residuals for Iron are not normally distributed (reject the null hypothesis).

# %%
# Kruskall-Wallis Test 
from scipy.stats import kruskal

for nutrient in nutrients:
    # Prepare data for Kruskal-Wallis: group the data by 'NIH_Food_Group'
    grouped_data = [group[nutrient].dropna().values for name, group in nih_food_data.groupby('NIH_Food_Group')]
    
    # Perform Kruskal-Wallis H test
    stat, p_value = kruskal(*grouped_data)
    
    # Display the results
    print(f"\nKruskal-Wallis H Test for {nutrient}:")
    print(f"Statistic: {stat}, p-value: {p_value}")
    
    # Interpretation of statistical significance
    if p_value < 0.05:
        print(f"The differences between the NIH_Food_Group categories for {nutrient} are statistically significant (p = {p_value}).")
    else:
        print(f"The differences between the NIH_Food_Group categories for {nutrient} are not statistically significant (p = {p_value}).")
# Out:
# Kruskal-Wallis H Test for Calories:
# Statistic: 471.2737574005219, p-value: 1.2922497713175395e-98
# The differences between the NIH_Food_Group categories for Calories are statistically significant (p = 1.2922497713175395e-98).
#
# Kruskal-Wallis H Test for Fats:
# Statistic: 165.56060683284528, p-value: 3.929042680580129e-33
# The differences between the NIH_Food_Group categories for Fats are statistically significant (p = 3.929042680580129e-33).
#
# Kruskal-Wallis H Test for Saturated Fat:
# Statistic: 200.34599184476986, p-value: 1.6016303380888293e-40
# The differences between the NIH_Food_Group categories for Saturated Fat are statistically significant (p = 1.6016303380888293e-40).
#
# Kruskal-Wallis H Test for Trans Fat:
# Statistic: 493.78330416909284, p-value: 1.8357720236471274e-103
# The differences between the NIH_Food_Group categories for Trans Fat are statistically significant (p = 1.8357720236471274e-103).
#
# Kruskal-Wallis H Test for Cholesterol:
# Statistic: 488.1196255322843, p-value: 3.045730637832233e-102
# The differences between the NIH_Food_Group categories for Cholesterol are statistically significant (p = 3.045730637832233e-102).
#
# Kruskal-Wallis H Test for Sodium:
# Statistic: 352.1419887598428, p-value: 5.353248762774402e-73
# The differences between the NIH_Food_Group categories for Sodium are statistically significant (p = 5.353248762774402e-73).
#
# Kruskal-Wallis H Test for Carbs:
# Statistic: 298.29197233974975, p-value: 1.8999314434976785e-61
# The differences between the NIH_Food_Group categories for Carbs are statistically significant (p = 1.8999314434976785e-61).
#
# Kruskal-Wallis H Test for Fiber:
# Statistic: 408.5335327405887, p-value: 4.089668649610674e-85
# The differences between the NIH_Food_Group categories for Fiber are statistically significant (p = 4.089668649610674e-85).
#
# Kruskal-Wallis H Test for Sugar:
# Statistic: 134.8503932864948, p-value: 1.2220923275727768e-26
# The differences between the NIH_Food_Group categories for Sugar are statistically significant (p = 1.2220923275727768e-26).
#
# Kruskal-Wallis H Test for Protein:
# Statistic: 92.06973168603075, p-value: 1.1254284235602747e-17
# The differences between the NIH_Food_Group categories for Protein are statistically significant (p = 1.1254284235602747e-17).
#
# Kruskal-Wallis H Test for Calcium:
# Statistic: 186.17638970920774, p-value: 1.6534839250265655e-37
# The differences between the NIH_Food_Group categories for Calcium are statistically significant (p = 1.6534839250265655e-37).
#
# Kruskal-Wallis H Test for Potassium:
# Statistic: 233.54547339532746, p-value: 1.34071251497807e-47
# The differences between the NIH_Food_Group categories for Potassium are statistically significant (p = 1.34071251497807e-47).
#
# Kruskal-Wallis H Test for Iron:
# Statistic: 60.68563115267257, p-value: 3.265656575821042e-11
# The differences between the NIH_Food_Group categories for Iron are statistically significant (p = 3.265656575821042e-11).
